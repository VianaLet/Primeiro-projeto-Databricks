# %%
# %sql
SELECT *
FROM clientes;

# %%
# %sql
SELECT id_cliente, primeiro_nome, cidade
FROM clientes;

# %%
# %sql
SELECT id_cliente, idade
FROM clientes
limit 10;

# %%
# %sql
SELECT  DISTINCT cidade, idade
FROM clientes;

# %%
# %sql
SELECT *
FROM produtos
WHERE categoria = 'Beleza'

# %%
# %sql
SELECT *
FROM produtos
ORDER BY preco_unitario DESC;

# %%
# %sql
SELECT count(*) AS 30anos
FROM clientes
WHERE idade = 30;

# %%
# %sql
SELECT *
FROM clientes
WHERE primeiro_nome LIKE "A%" /* Filtrando somente clientes em que o nome começa com a letra "A" \*

# %%
# %sql
SELECT *
FROM clientes
WHERE primeiro_nome = "Letícia"

# %%
# %sql
SELECT categoria, avg(preco_unitario)
FROM produtos
GROUP BY categoria

# %%
# %sql
SELECT id_produto, nome_produto
FROM produtos
LIMIT 10

# %%
# %sql
SELECT
FROM produtos
JOIN vendas
